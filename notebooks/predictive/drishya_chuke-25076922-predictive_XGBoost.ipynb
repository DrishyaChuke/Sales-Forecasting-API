# %%
# %load_ext autoreload
# %autoreload 2

# %%
pip install -i https://test.pypi.org/simple/ my_krml_25076922==2024.0.3.3
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: my_krml_25076922==2024.0.3.3 in /Users/vega7unk/anaconda3/lib/python3.11/site-packages (2024.0.3.3)
# Requirement already satisfied: pandas==2.2.2 in /Users/vega7unk/anaconda3/lib/python3.11/site-packages (from my_krml_25076922==2024.0.3.3) (2.2.2)
# Requirement already satisfied: scikit-learn==1.5.1 in /Users/vega7unk/anaconda3/lib/python3.11/site-packages (from my_krml_25076922==2024.0.3.3) (1.5.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.0.0 in /Users/vega7unk/anaconda3/lib/python3.11/site-packages (from my_krml_25076922==2024.0.3.3) (4.65.0)
# Requirement already satisfied: numpy>=1.23.2 in /Users/vega7unk/anaconda3/lib/python3.11/site-packages (from pandas==2.2.2->my_krml_25076922==2024.0.3.3) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vega7unk/anaconda3/lib/python3.11/site-packages (from pandas==2.2.2->my_krml_25076922==2024.0.3.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/vega7unk/anaconda3/lib/python3.11/site-packages (from pandas==2.2.2->my_krml_25076922==2024.0.3.3) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in /Users/vega7unk/anaconda3/lib/python3.11/site-packages (from pandas==2.2.2->my_krml_25076922==2024.0.3.3) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in /Users/vega7unk/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.5.1->my_krml_25076922==2024.0.3.3) (1.11.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/vega7unk/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.5.1->my_krml_25076922==2024.0.3.3) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/vega7unk/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.5.1->my_krml_25076922==2024.0.3.3) (3.5.0)
# Requirement already satisfied: six>=1.5 in /Users/vega7unk/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2->my_krml_25076922==2024.0.3.3) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

import os
# Out:
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
path ='/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT2/Project/adv_mla_at2/data/processed'

sales_data = pd.read_csv(f'{path}/df_pred.csv')

# %%
sales_data.head()
# Out:
#          item_id store_id        date  total_sales  day_of_week  month  year
# 0  HOBBIES_1_001     CA_1  2011-01-29          0.0            5      1  2011
# 1  HOBBIES_1_002     CA_1  2011-01-29          0.0            5      1  2011
# 2  HOBBIES_1_003     CA_1  2011-01-29          0.0            5      1  2011
# 3  HOBBIES_1_004     CA_1  2011-01-29          0.0            5      1  2011
# 4  HOBBIES_1_005     CA_1  2011-01-29          0.0            5      1  2011

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47107050 entries, 0 to 47107049
# Data columns (total 7 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   item_id      object
#  1   store_id     object
#  2   date         object
#  3   total_sales  float64
#  4   day_of_week  int64
#  5   month        int64
#  6   year         int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.5+ GB

# %%
from sklearn.preprocessing import LabelEncoder

le_item = LabelEncoder()
le_store = LabelEncoder()

sales_data['item_id'] = le_item.fit_transform(sales_data['item_id'])
sales_data['store_id'] = le_store.fit_transform(sales_data['store_id'])

# %%
sales_data.head()
# Out:
#    item_id  store_id        date  total_sales  day_of_week  month  year
# 0     1437         0  2011-01-29          0.0            5      1  2011
# 1     1438         0  2011-01-29          0.0            5      1  2011
# 2     1439         0  2011-01-29          0.0            5      1  2011
# 3     1440         0  2011-01-29          0.0            5      1  2011
# 4     1441         0  2011-01-29          0.0            5      1  2011

# %%
from sklearn.preprocessing import StandardScaler

X = sales_data[['item_id', 'store_id', 'day_of_week', 'month', 'year']]
y = sales_data['total_sales']

scaler = StandardScaler()
X_scaled = scaler.fit(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
import xgboost as xgb

model = xgb.XGBRegressor()
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Make predictions on the validation set
y_pred = model.predict(X_val)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Evaluate the model
rmse = mean_squared_error(y_val, y_pred, squared=False)  # RMSE
mae = mean_absolute_error(y_val, y_pred)

print(f"RMSE Validation: {rmse}")
print(f"MAE Validation: {mae}")
# Out:
# RMSE Validation: 8.867779334911672
# MAE Validation: 4.103078436951001
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
model_1 = xgb.XGBRegressor(
    n_estimators=100,          # Number of trees
    learning_rate=0.1,         # Step size shrinkage
    max_depth=6,               # Maximum tree depth for base learners
    subsample=0.8,             # Subsample ratio of the training instance
    colsample_bytree=0.8,      # Subsample ratio of columns when constructing each tree
    random_state=42
)

# Fit the model on the training data
model_1.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=10, verbose=True)
# Out:
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:9.17839
# [1]	validation_0-rmse:9.15781
# [2]	validation_0-rmse:9.13933
# [3]	validation_0-rmse:9.12405
# [4]	validation_0-rmse:9.11308
# [5]	validation_0-rmse:9.09797
# [6]	validation_0-rmse:9.09206
# [7]	validation_0-rmse:9.07932
# [8]	validation_0-rmse:9.07041
# [9]	validation_0-rmse:9.06282
# [10]	validation_0-rmse:9.05481
# [11]	validation_0-rmse:9.04816
# [12]	validation_0-rmse:9.04101
# [13]	validation_0-rmse:9.03525
# [14]	validation_0-rmse:9.03237
# [15]	validation_0-rmse:9.02621
# [16]	validation_0-rmse:9.02028
# [17]	validation_0-rmse:9.01500
# [18]	validation_0-rmse:9.00900
# [19]	validation_0-rmse:9.00729
# [20]	validation_0-rmse:9.00428
# [21]	validation_0-rmse:9.00041
# [22]	validation_0-rmse:8.99747
# [23]	validation_0-rmse:8.99530
# [24]	validation_0-rmse:8.99313
# [25]	validation_0-rmse:8.99146
# [26]	validation_0-rmse:8.98916
# [27]	validation_0-rmse:8.98649
# [28]	validation_0-rmse:8.98512
# [29]	validation_0-rmse:8.98248
# [30]	validation_0-rmse:8.98081
# [31]	validation_0-rmse:8.97909
# [32]	validation_0-rmse:8.97737
# [33]	validation_0-rmse:8.97652
# [34]	validation_0-rmse:8.97548
# [35]	validation_0-rmse:8.97498
# [36]	validation_0-rmse:8.97227
# [37]	validation_0-rmse:8.97174
# [38]	validation_0-rmse:8.97144
# [39]	validation_0-rmse:8.97112
# [40]	validation_0-rmse:8.96869
# [41]	validation_0-rmse:8.96736
# [42]	validation_0-rmse:8.96578
# [43]	validation_0-rmse:8.96538
# [44]	validation_0-rmse:8.96341
# [45]	validation_0-rmse:8.96183
# [46]	validation_0-rmse:8.96013
# [47]	validation_0-rmse:8.95962
# [48]	validation_0-rmse:8.95844
# [49]	validation_0-rmse:8.95824
# [50]	validation_0-rmse:8.95681
# [51]	validation_0-rmse:8.95656
# [52]	validation_0-rmse:8.95521
# [53]	validation_0-rmse:8.95408
# [54]	validation_0-rmse:8.95232
# [55]	validation_0-rmse:8.95167
# [56]	validation_0-rmse:8.94993
# [57]	validation_0-rmse:8.94906
# [58]	validation_0-rmse:8.94884
# [59]	validation_0-rmse:8.94700
# [60]	validation_0-rmse:8.94684
# [61]	validation_0-rmse:8.94597
# [62]	validation_0-rmse:8.94585
# [63]	validation_0-rmse:8.94495
# [64]	validation_0-rmse:8.94389
# [65]	validation_0-rmse:8.94297
# [66]	validation_0-rmse:8.94281
# [67]	validation_0-rmse:8.94241
# [68]	validation_0-rmse:8.94222
# [69]	validation_0-rmse:8.94211
# [70]	validation_0-rmse:8.94124
# [71]	validation_0-rmse:8.94111
# [72]	validation_0-rmse:8.94077
# [73]	validation_0-rmse:8.94063
# [74]	validation_0-rmse:8.93969
# [75]	validation_0-rmse:8.93662
# [76]	validation_0-rmse:8.93584
# [77]	validation_0-rmse:8.93346
# [78]	validation_0-rmse:8.93316
# [79]	validation_0-rmse:8.93243
# [80]	validation_0-rmse:8.93070
# [81]	validation_0-rmse:8.93062
# [82]	validation_0-rmse:8.93052
# [83]	validation_0-rmse:8.92971
# [84]	validation_0-rmse:8.92962
# [85]	validation_0-rmse:8.92920
# [86]	validation_0-rmse:8.92897
# [87]	validation_0-rmse:8.92749
# [88]	validation_0-rmse:8.92611
# [89]	validation_0-rmse:8.92544
# [90]	validation_0-rmse:8.92515
# [91]	validation_0-rmse:8.92487
# [92]	validation_0-rmse:8.92432
# [93]	validation_0-rmse:8.92272
# [94]	validation_0-rmse:8.92265
# [95]	validation_0-rmse:8.92258
# [96]	validation_0-rmse:8.92243
# [97]	validation_0-rmse:8.92062
# [98]	validation_0-rmse:8.91910
# [99]	validation_0-rmse:8.91886
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
y_pred_1 = model_1.predict(X_val)

# %%
# Evaluate the model
rmse = mean_squared_error(y_val, y_pred_1, squared=False)  # RMSE
mae = mean_absolute_error(y_val, y_pred_1)

print(f"RMSE Validation: {rmse}")
print(f"MAE Validation: {mae}")
# Out:
# RMSE Validation: 8.91885900411708
# MAE Validation: 4.129478078824783
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
import joblib

joblib.dump(model, '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT2/Project/adv_mla_at2/models/predictive/xgb_predictive_model.pkl')
# Out:
# ['/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT2/Project/adv_mla_at2/models/predictive/xgb_predictive_model.pkl']

# %%
joblib.dump(scaler, '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT2/Project/adv_mla_at2/models/predictive/scaler.pkl')
# Out:
# ['/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT2/Project/adv_mla_at2/models/predictive/scaler.pkl']

# %%
import pickle

with open("/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT2/Project/adv_mla_at2/models/predictive/le_store.pkl", "wb") as f:
    pickle.dump(le_store, f)

with open("/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT2/Project/adv_mla_at2/models/predictive/le_item.pkl", "wb") as f:
    pickle.dump(le_item, f)
